# %%
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OrdinalEncoder
from xgboost import XGBClassifier

# %%
# Load the training and test data
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
# Combine train and test data for consistent encoding
train_data['is_train'] = 1
test_data['is_train'] = 0
combined_data = pd.concat([train_data, test_data], sort=False)

# %%
# Extracting numerical features
num_features = combined_data.select_dtypes(exclude = ['object', 'bool']).columns.tolist()
combined_data[num_features].head()

# Extracting categorical features
cat_features = combined_data.select_dtypes(include = ['object']).columns.tolist()
combined_data[cat_features].head()
# Out:
#   PassengerId HomePlanet CryoSleep  Cabin  Destination    VIP  \
# 0     0001_01     Europa     False  B/0/P  TRAPPIST-1e  False
# 1     0002_01      Earth     False  F/0/S  TRAPPIST-1e  False
# 2     0003_01     Europa     False  A/0/S  TRAPPIST-1e   True
# 3     0003_02     Europa     False  A/0/S  TRAPPIST-1e  False
# 4     0004_01      Earth     False  F/1/S  TRAPPIST-1e  False
#
#                 Name Transported
# 0    Maham Ofracculy       False
# 1       Juanna Vines        True
# 2      Altark Susent       False
# 3       Solam Susent       False
# 4  Willy Santantines        True

# %%
# Impute missing values with Median for each Numerical feature
for col in num_features:
    combined_data[col] = combined_data[col].fillna(combined_data[col].median())

# Impute missing values with Mode for each Categorical feature
for col in cat_features:
    combined_data[col] = combined_data[col].fillna(combined_data[col].mode()[0])

# %%
# Encode categorical features
encoder = OrdinalEncoder()
combined_data[['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP']] = encoder.fit_transform(combined_data[['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP']])

# Split the data back into train and test sets
train_data = combined_data[combined_data['is_train'] == 1].drop(['is_train'], axis=1)
test_data = combined_data[combined_data['is_train'] == 0].drop(['is_train'], axis=1)

# Select features and target
features = train_data.drop(['PassengerId', 'Name', 'Transported'], axis=1).columns
target = ['Transported']

X = train_data[features]
y = train_data[target]

# %%
# Define the objective function for Optuna
def objective(trial):
    xgb_params = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
        'n_estimators': trial.suggest_int('n_estimators', 50, 200),
        'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
        'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }
    xgb = XGBClassifier(**xgb_params)
    score = cross_val_score(xgb, X, y.values.ravel(), cv=5, scoring='accuracy').mean()
    return score

# %%
# Optimize the hyperparameters using Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-03-21 13:32:50,612] A new study created in memory with name: no-name-0fbd0947-1394-4cf6-ae51-f06e36a2585d
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:32:58,980] Trial 0 finished with value: 0.7817854261969532 and parameters: {'max_depth': 8, 'learning_rate': 0.0454583697469847, 'n_estimators': 54, 'subsample': 0.8, 'colsample_bytree': 0.7}. Best is trial 0 with value: 0.7817854261969532.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:33:11,049] Trial 1 finished with value: 0.7906413550636551 and parameters: {'max_depth': 6, 'learning_rate': 0.015341279950847539, 'n_estimators': 123, 'subsample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:33:25,233] Trial 2 finished with value: 0.7771832283278552 and parameters: {'max_depth': 9, 'learning_rate': 0.03953914296044886, 'n_estimators': 61, 'subsample': 0.7, 'colsample_bytree': 1.0}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:33:45,986] Trial 3 finished with value: 0.7769527478657562 and parameters: {'max_depth': 10, 'learning_rate': 0.02359178968938136, 'n_estimators': 70, 'subsample': 0.8, 'colsample_bytree': 1.0}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:34:16,066] Trial 4 finished with value: 0.7867312603105763 and parameters: {'max_depth': 8, 'learning_rate': 0.020906928791949074, 'n_estimators': 144, 'subsample': 0.5, 'colsample_bytree': 0.8}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:34:20,464] Trial 5 finished with value: 0.780516228590562 and parameters: {'max_depth': 3, 'learning_rate': 0.020392072447538982, 'n_estimators': 84, 'subsample': 0.9, 'colsample_bytree': 0.6}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:35:04,590] Trial 6 finished with value: 0.7595812177282687 and parameters: {'max_depth': 10, 'learning_rate': 0.14165647429345823, 'n_estimators': 188, 'subsample': 0.9, 'colsample_bytree': 1.0}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:35:30,305] Trial 7 finished with value: 0.7563617702858209 and parameters: {'max_depth': 7, 'learning_rate': 0.16478150528966248, 'n_estimators': 188, 'subsample': 0.9, 'colsample_bytree': 0.5}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:35:49,913] Trial 8 finished with value: 0.7833957454749267 and parameters: {'max_depth': 5, 'learning_rate': 0.053472234637920876, 'n_estimators': 177, 'subsample': 0.9, 'colsample_bytree': 1.0}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:35:56,387] Trial 9 finished with value: 0.7901788721610967 and parameters: {'max_depth': 5, 'learning_rate': 0.012306379976891033, 'n_estimators': 76, 'subsample': 0.5, 'colsample_bytree': 0.8}. Best is trial 1 with value: 0.7906413550636551.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:36:05,365] Trial 10 finished with value: 0.7924788461551188 and parameters: {'max_depth': 5, 'learning_rate': 0.012391328180232775, 'n_estimators': 115, 'subsample': 0.7, 'colsample_bytree': 0.7}. Best is trial 10 with value: 0.7924788461551188.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:36:17,302] Trial 11 finished with value: 0.7920189439984754 and parameters: {'max_depth': 5, 'learning_rate': 0.010791778565112266, 'n_estimators': 116, 'subsample': 0.7, 'colsample_bytree': 0.7}. Best is trial 10 with value: 0.7924788461551188.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:36:23,531] Trial 12 finished with value: 0.7766046780320952 and parameters: {'max_depth': 3, 'learning_rate': 0.010743034551570151, 'n_estimators': 113, 'subsample': 0.6, 'colsample_bytree': 0.7}. Best is trial 10 with value: 0.7924788461551188.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:36:31,486] Trial 13 finished with value: 0.7894880263315491 and parameters: {'max_depth': 5, 'learning_rate': 0.010027162759011709, 'n_estimators': 101, 'subsample': 0.7, 'colsample_bytree': 0.6}. Best is trial 10 with value: 0.7924788461551188.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:36:39,856] Trial 14 finished with value: 0.7912136851000303 and parameters: {'max_depth': 4, 'learning_rate': 0.015366757966006547, 'n_estimators': 134, 'subsample': 0.6, 'colsample_bytree': 0.6}. Best is trial 10 with value: 0.7924788461551188.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:37:02,458] Trial 15 finished with value: 0.7881117608561724 and parameters: {'max_depth': 6, 'learning_rate': 0.030965848003597914, 'n_estimators': 153, 'subsample': 0.6, 'colsample_bytree': 0.9}. Best is trial 10 with value: 0.7924788461551188.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:37:11,022] Trial 16 finished with value: 0.785232707182613 and parameters: {'max_depth': 4, 'learning_rate': 0.010195472934796227, 'n_estimators': 96, 'subsample': 1.0, 'colsample_bytree': 0.7}. Best is trial 10 with value: 0.7924788461551188.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:37:26,617] Trial 17 finished with value: 0.7845434495043976 and parameters: {'max_depth': 7, 'learning_rate': 0.015452213207052087, 'n_estimators': 161, 'subsample': 0.7, 'colsample_bytree': 0.5}. Best is trial 10 with value: 0.7924788461551188.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# ...
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:41:49,064] Trial 43 finished with value: 0.7950106240706833 and parameters: {'max_depth': 4, 'learning_rate': 0.019115932881788804, 'n_estimators': 200, 'subsample': 0.8, 'colsample_bytree': 0.9}. Best is trial 43 with value: 0.7950106240706833.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:42:04,903] Trial 44 finished with value: 0.7935155119372733 and parameters: {'max_depth': 4, 'learning_rate': 0.01864469127465661, 'n_estimators': 178, 'subsample': 0.9, 'colsample_bytree': 0.9}. Best is trial 43 with value: 0.7950106240706833.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:42:14,379] Trial 45 finished with value: 0.792825195491503 and parameters: {'max_depth': 4, 'learning_rate': 0.01957537711192755, 'n_estimators': 180, 'subsample': 1.0, 'colsample_bytree': 0.9}. Best is trial 43 with value: 0.7950106240706833.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:42:25,480] Trial 46 finished with value: 0.7898349050517108 and parameters: {'max_depth': 4, 'learning_rate': 0.019337150396845894, 'n_estimators': 181, 'subsample': 1.0, 'colsample_bytree': 0.9}. Best is trial 43 with value: 0.7950106240706833.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:42:40,932] Trial 47 finished with value: 0.7901801294475682 and parameters: {'max_depth': 4, 'learning_rate': 0.02989917963554966, 'n_estimators': 188, 'subsample': 0.9, 'colsample_bytree': 1.0}. Best is trial 43 with value: 0.7950106240706833.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:42:51,967] Trial 48 finished with value: 0.7894900115207145 and parameters: {'max_depth': 4, 'learning_rate': 0.02340788123348434, 'n_estimators': 169, 'subsample': 1.0, 'colsample_bytree': 0.9}. Best is trial 43 with value: 0.7950106240706833.
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:7: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1),
# /var/folders/pf/bjt8ngz536v9z189p8lxdv1m0000gn/T/ipykernel_11822/3205294494.py:8: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1),
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-03-21 13:43:04,302] Trial 49 finished with value: 0.793745065977762 and parameters: {'max_depth': 3, 'learning_rate': 0.04273860712200842, 'n_estimators': 181, 'subsample': 0.9, 'colsample_bytree': 0.9}. Best is trial 43 with value: 0.7950106240706833.

# %%
# Train the model with the best hyperparameters
best_params = study.best_params
xgb_best = XGBClassifier(**best_params)
xgb_best.fit(X, y.values.ravel())

# Predict Transported for test data
X_test = test_data[features]
y_test_pred = xgb_best.predict(X_test)

# %%
# Create submission file
submission = pd.DataFrame({'PassengerId': test_data['PassengerId'], 'Transported': y_test_pred})
submission.to_csv('XGBoost_submission.csv', index=False)

print("Submission file created: submission.csv")
# Out:
# Submission file created: submission.csv
